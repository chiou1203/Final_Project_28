# %%
#import common libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import scipy
import os
import csv

# %%
#read the csv data, you can change the file name according to yours
raw_data = pd.read_csv(r'C:\Users\user\Desktop\dataset\train.csv', delimiter=',')

# %%
#encode categorical features into numbers, for lose_reason, if no result yet, set to 0
cleanup_nums1 = {"type": {"short service": 0, "long service": 1, "clear": 2, "push/rush": 3, "smash": 4, "defensive shot": 5,
                          "drive": 6, "net shot": 7, "lob": 8, "drop": 9}}
cleanup_nums2 = {"lose_reason": {"out": 1, "touched the net": 2, "not pass over the net": 3, "opponent's ball landed": 4, "misjudged": 5}}
data = raw_data.replace(cleanup_nums1)
data = data.replace(cleanup_nums2)
data['lose_reason'].fillna(0, inplace=True)

# %%
#these are the features that may be important for prediction, to see what method was used for feature selection, check the description on Inter-Stroke Features Selection
selected = ['match_id', 'set', 'rally_id', 'ball_round', 'rally_length', 
            'landing_height', 'landing_area', 
            'player_location_y','landing_x', 'landing_y','type']

# %%
#some of the column may need further scaling
selected_data = data[selected]
selected_data.iloc[:,5:-1]
# Out:
#        landing_height  landing_area  player_location_y  landing_x  landing_y
# 0                 2.0             7             308.95   0.773171   0.519687
# 1                 2.0             7             594.37   0.086585  -0.237240
# 2                 1.0             3             378.28   1.402439   1.638490
# 3                 1.0             4             809.08   1.358537  -1.434167
# 4                 2.0             1             268.22   1.487805   0.359844
# ...               ...           ...                ...        ...        ...
# 30167             2.0             7             659.34   0.051220  -0.436198
# 30168             2.0             7             349.63   0.145122   0.290938
# 30169             2.0             7             583.50  -0.097561  -0.277240
# 30170             1.0             9             401.02  -0.080488   1.515417
# 30171             2.0             6             743.26   1.181707  -0.903958
#
# [30172 rows x 5 columns]

# %%
train = selected_data
from sklearn.preprocessing import MinMaxScaler

# Select the columns that need scaling
columns_to_scale = selected_data.columns[5:-1]

# Create an instance of MinMaxScaler
scaler = MinMaxScaler(feature_range=(-1, 1))

# Fit and transform the selected columns using the scaler
train[columns_to_scale] = scaler.fit_transform(train[columns_to_scale])
train.iloc[:,5:-1]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_32628\3694319556.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[columns_to_scale] = scaler.fit_transform(train[columns_to_scale])
#        landing_height  landing_area  player_location_y  landing_x  landing_y
# 0                 1.0      0.333333          -0.476638   0.214696   0.267701
# 1                 1.0      0.333333           0.346836   0.018631  -0.118990
# 2                -1.0     -0.555556          -0.276612   0.394393   0.839262
# 3                -1.0     -0.333333           0.966302   0.381856  -0.730463
# 4                 1.0     -1.000000          -0.594149   0.418771   0.186042
# ...               ...           ...                ...        ...        ...
# 30167             1.0      0.333333           0.534283   0.008532  -0.220632
# 30168             1.0      0.333333          -0.359271   0.035347   0.150839
# 30169             1.0      0.333333           0.315474  -0.033954  -0.139425
# 30170            -1.0      0.777778          -0.211004  -0.029079   0.776388
# 30171             1.0      0.111111           0.776403   0.331360  -0.459596
#
# [30172 rows x 5 columns]

# %%
#group the data by the same rally for we need to make sure the sequence our model observe is on the same rally
grouped_data = train.groupby(['set', 'match_id', 'rally_id'])

# %%
#generate past information(past 4 strokes) and future information(we need to predict future stroke)
sequence_length = 1
future_length = 1
sequences = []
futures = []
for _, group in grouped_data:
    rally_data = group[[ 'landing_height', 'landing_area', 
            'player_location_y','landing_y', 'type']]  # Select the relevant features for the input
    series_shift= rally_data.shift()
    for col in series_shift.columns:
        series_shift.rename(columns={col: 'prev_' + col}, inplace=True)
    merged = pd.merge(rally_data, series_shift, left_index=True, right_index=True)
    merged = merged.dropna(axis=0)
    merged = merged[['prev_landing_height', 'prev_landing_area', 
            'prev_player_location_y','prev_landing_y', 'prev_type','landing_height', 'landing_area', 
            'player_location_y','landing_y', 'type']]
    num_samples = len(merged)
    for i in range(num_samples):
        sequence = merged.iloc[i]
        sequences.append(sequence)

# %%
train = np.array(sequences)

# %%
train.shape
# Out:
# (27899, 10)

# %%
X = train[:, :-1]
y = train[:, -1]

# %%
y.shape
# Out:
# (27899,)

# %%
#split the datasets 70% training, 20% testing, 10% validating

from sklearn.model_selection import train_test_split

# Shuffle the data
indices = np.arange(X.shape[0])
np.random.shuffle(indices)
X_shuffled = X[indices]
y_shuffled = y[indices]

# Split the shuffled data into train, test, and validation sets
X_train, X_test, y_train, y_test = train_test_split(X_shuffled, y_shuffled, test_size=0.3, random_state=42)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.33, random_state=42)

# Verify the shapes of the data splits
print("Train data shape:", X_train.shape)
print("Test data shape:", X_test.shape)
print("Validation data shape:", X_val.shape)
print("Train target shape:", y_train.shape)
print("Test target shape:", y_test.shape)
print("Validation target shape:", y_val.shape)
# Out:
# Train data shape: (19529, 9)
# Test data shape: (5607, 9)
# Validation data shape: (2763, 9)
# Train target shape: (19529,)
# Test target shape: (5607,)
# Validation target shape: (2763,)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(128, activation='elu', input_shape=(9,)))
model.add(Dropout(0.1))
model.add(Dense(64, activation='elu'))
model.add(Dropout(0.2))
model.add(Dense(32, activation='elu'))
model.add(Dropout(0.1))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_80 (Dense)            (None, 128)               1280
#
#  dropout_23 (Dropout)        (None, 128)               0
#
#  dense_81 (Dense)            (None, 64)                8256
#
#  dropout_24 (Dropout)        (None, 64)                0
#
#  dense_82 (Dense)            (None, 32)                2080
#
#  dropout_25 (Dropout)        (None, 32)                0
#
#  dense_83 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 11,946
# Trainable params: 11,946
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-3)
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])


# Training the model
history = model.fit(X_train, y_train, batch_size=32, epochs=100, validation_data=(X_val, y_val))

# Evaluating the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/100
# 611/611 [==============================] - 3s 4ms/step - loss: 1.1452 - accuracy: 0.6122 - val_loss: 0.9394 - val_accuracy: 0.6782
# Epoch 2/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.9425 - accuracy: 0.6907 - val_loss: 0.8003 - val_accuracy: 0.7409
# Epoch 3/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.8315 - accuracy: 0.7261 - val_loss: 0.6897 - val_accuracy: 0.7637
# Epoch 4/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.7036 - accuracy: 0.7545 - val_loss: 0.5689 - val_accuracy: 0.7897
# Epoch 5/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.6073 - accuracy: 0.7880 - val_loss: 0.5180 - val_accuracy: 0.8223
# Epoch 6/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.5691 - accuracy: 0.8080 - val_loss: 0.4858 - val_accuracy: 0.8310
# Epoch 7/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.5366 - accuracy: 0.8179 - val_loss: 0.4670 - val_accuracy: 0.8360
# Epoch 8/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.5257 - accuracy: 0.8250 - val_loss: 0.4529 - val_accuracy: 0.8451
# Epoch 9/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.5001 - accuracy: 0.8342 - val_loss: 0.4506 - val_accuracy: 0.8418
# Epoch 10/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.4913 - accuracy: 0.8339 - val_loss: 0.4620 - val_accuracy: 0.8353
# Epoch 11/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.4817 - accuracy: 0.8369 - val_loss: 0.4442 - val_accuracy: 0.8451
# Epoch 12/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.4806 - accuracy: 0.8382 - val_loss: 0.4507 - val_accuracy: 0.8422
# Epoch 13/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4670 - accuracy: 0.8439 - val_loss: 0.4320 - val_accuracy: 0.8552
# Epoch 14/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4623 - accuracy: 0.8444 - val_loss: 0.4525 - val_accuracy: 0.8411
# Epoch 15/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4627 - accuracy: 0.8412 - val_loss: 0.4297 - val_accuracy: 0.8541
# Epoch 16/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.4473 - accuracy: 0.8490 - val_loss: 0.4147 - val_accuracy: 0.8599
# Epoch 17/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.4476 - accuracy: 0.8508 - val_loss: 0.4354 - val_accuracy: 0.8476
# Epoch 18/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.4415 - accuracy: 0.8512 - val_loss: 0.4303 - val_accuracy: 0.8527
# Epoch 19/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.4468 - accuracy: 0.8482 - val_loss: 0.4193 - val_accuracy: 0.8523
# Epoch 20/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4382 - accuracy: 0.8520 - val_loss: 0.4099 - val_accuracy: 0.8574
# Epoch 21/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4341 - accuracy: 0.8549 - val_loss: 0.4115 - val_accuracy: 0.8549
# Epoch 22/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4367 - accuracy: 0.8527 - val_loss: 0.4132 - val_accuracy: 0.8596
# Epoch 23/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.4326 - accuracy: 0.8548 - val_loss: 0.4017 - val_accuracy: 0.8628
# Epoch 24/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.4326 - accuracy: 0.8541 - val_loss: 0.4104 - val_accuracy: 0.8588
# Epoch 25/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.4261 - accuracy: 0.8554 - val_loss: 0.4176 - val_accuracy: 0.8531
# Epoch 26/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.4276 - accuracy: 0.8535 - val_loss: 0.4088 - val_accuracy: 0.8607
# Epoch 27/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4257 - accuracy: 0.8561 - val_loss: 0.4332 - val_accuracy: 0.8505
# Epoch 28/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4213 - accuracy: 0.8566 - val_loss: 0.4118 - val_accuracy: 0.8531
# Epoch 29/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4263 - accuracy: 0.8565 - val_loss: 0.4032 - val_accuracy: 0.8599
# Epoch 30/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.4195 - accuracy: 0.8566 - val_loss: 0.4045 - val_accuracy: 0.8581
# Epoch 31/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.4210 - accuracy: 0.8588 - val_loss: 0.4008 - val_accuracy: 0.8592
# Epoch 32/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.4241 - accuracy: 0.8575 - val_loss: 0.3978 - val_accuracy: 0.8603
# Epoch 33/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.4154 - accuracy: 0.8582 - val_loss: 0.3952 - val_accuracy: 0.8636
# Epoch 34/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4146 - accuracy: 0.8619 - val_loss: 0.4052 - val_accuracy: 0.8545
# Epoch 35/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4170 - accuracy: 0.8580 - val_loss: 0.4045 - val_accuracy: 0.8617
# Epoch 36/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4133 - accuracy: 0.8586 - val_loss: 0.3979 - val_accuracy: 0.8599
# Epoch 37/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.4132 - accuracy: 0.8593 - val_loss: 0.4000 - val_accuracy: 0.8628
# Epoch 38/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.4149 - accuracy: 0.8604 - val_loss: 0.3939 - val_accuracy: 0.8599
# Epoch 39/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.4096 - accuracy: 0.8605 - val_loss: 0.4046 - val_accuracy: 0.8599
# Epoch 40/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.4111 - accuracy: 0.8614 - val_loss: 0.4006 - val_accuracy: 0.8610
# Epoch 41/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.4110 - accuracy: 0.8610 - val_loss: 0.4012 - val_accuracy: 0.8646
# Epoch 42/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4127 - accuracy: 0.8608 - val_loss: 0.4013 - val_accuracy: 0.8581
# Epoch 43/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4047 - accuracy: 0.8632 - val_loss: 0.4034 - val_accuracy: 0.8596
# Epoch 44/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.4106 - accuracy: 0.8611 - val_loss: 0.3947 - val_accuracy: 0.8632
# Epoch 45/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.4106 - accuracy: 0.8597 - val_loss: 0.4149 - val_accuracy: 0.8545
# Epoch 46/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.4061 - accuracy: 0.8637 - val_loss: 0.4028 - val_accuracy: 0.8596
# Epoch 47/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.4061 - accuracy: 0.8631 - val_loss: 0.3982 - val_accuracy: 0.8610
# Epoch 48/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.4048 - accuracy: 0.8629 - val_loss: 0.4169 - val_accuracy: 0.8567
# Epoch 49/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4078 - accuracy: 0.8602 - val_loss: 0.4012 - val_accuracy: 0.8628
# Epoch 50/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4049 - accuracy: 0.8624 - val_loss: 0.3989 - val_accuracy: 0.8614
# Epoch 51/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.4062 - accuracy: 0.8618 - val_loss: 0.3989 - val_accuracy: 0.8617
# Epoch 52/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.4070 - accuracy: 0.8631 - val_loss: 0.3981 - val_accuracy: 0.8621
# Epoch 53/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.4061 - accuracy: 0.8628 - val_loss: 0.3910 - val_accuracy: 0.8632
# Epoch 54/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.4046 - accuracy: 0.8617 - val_loss: 0.3921 - val_accuracy: 0.8643
# Epoch 55/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.4062 - accuracy: 0.8625 - val_loss: 0.4017 - val_accuracy: 0.8588
# Epoch 56/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4002 - accuracy: 0.8638 - val_loss: 0.4016 - val_accuracy: 0.8574
# Epoch 57/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4011 - accuracy: 0.8652 - val_loss: 0.3938 - val_accuracy: 0.8596
# Epoch 58/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.3999 - accuracy: 0.8649 - val_loss: 0.3986 - val_accuracy: 0.8621
# Epoch 59/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.4049 - accuracy: 0.8636 - val_loss: 0.3979 - val_accuracy: 0.8617
# Epoch 60/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.3979 - accuracy: 0.8622 - val_loss: 0.3915 - val_accuracy: 0.8654
# Epoch 61/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.4019 - accuracy: 0.8650 - val_loss: 0.3843 - val_accuracy: 0.8650
# Epoch 62/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.4033 - accuracy: 0.8640 - val_loss: 0.3906 - val_accuracy: 0.8632
# Epoch 63/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.3980 - accuracy: 0.8636 - val_loss: 0.3961 - val_accuracy: 0.8588
# Epoch 64/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.3996 - accuracy: 0.8647 - val_loss: 0.4005 - val_accuracy: 0.8578
# Epoch 65/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.3995 - accuracy: 0.8652 - val_loss: 0.3901 - val_accuracy: 0.8657
# Epoch 66/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.3986 - accuracy: 0.8634 - val_loss: 0.3871 - val_accuracy: 0.8657
# Epoch 67/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.3974 - accuracy: 0.8661 - val_loss: 0.3873 - val_accuracy: 0.8588
# Epoch 68/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.3935 - accuracy: 0.8655 - val_loss: 0.3886 - val_accuracy: 0.8646
# Epoch 69/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.3993 - accuracy: 0.8641 - val_loss: 0.3890 - val_accuracy: 0.8668
# Epoch 70/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.3963 - accuracy: 0.8647 - val_loss: 0.4097 - val_accuracy: 0.8578
# Epoch 71/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.4010 - accuracy: 0.8621 - val_loss: 0.3932 - val_accuracy: 0.8632
# Epoch 72/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.3949 - accuracy: 0.8630 - val_loss: 0.3872 - val_accuracy: 0.8661
# Epoch 73/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.3958 - accuracy: 0.8667 - val_loss: 0.3860 - val_accuracy: 0.8672
# Epoch 74/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.3958 - accuracy: 0.8659 - val_loss: 0.3942 - val_accuracy: 0.8603
# Epoch 75/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.3959 - accuracy: 0.8657 - val_loss: 0.3904 - val_accuracy: 0.8675
# Epoch 76/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.3973 - accuracy: 0.8637 - val_loss: 0.3897 - val_accuracy: 0.8636
# Epoch 77/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.3969 - accuracy: 0.8650 - val_loss: 0.3923 - val_accuracy: 0.8614
# Epoch 78/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.3948 - accuracy: 0.8667 - val_loss: 0.3900 - val_accuracy: 0.8632
# Epoch 79/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.3934 - accuracy: 0.8674 - val_loss: 0.3890 - val_accuracy: 0.8639
# Epoch 80/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.3906 - accuracy: 0.8677 - val_loss: 0.3899 - val_accuracy: 0.8592
# Epoch 81/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.3946 - accuracy: 0.8669 - val_loss: 0.3911 - val_accuracy: 0.8596
# Epoch 82/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.3888 - accuracy: 0.8669 - val_loss: 0.3933 - val_accuracy: 0.8646
# Epoch 83/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.3923 - accuracy: 0.8665 - val_loss: 0.3842 - val_accuracy: 0.8610
# Epoch 84/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.3928 - accuracy: 0.8669 - val_loss: 0.4002 - val_accuracy: 0.8610
# Epoch 85/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.3928 - accuracy: 0.8664 - val_loss: 0.3837 - val_accuracy: 0.8650
# Epoch 86/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.3923 - accuracy: 0.8644 - val_loss: 0.3868 - val_accuracy: 0.8657
# Epoch 87/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.3896 - accuracy: 0.8678 - val_loss: 0.3945 - val_accuracy: 0.8625
# Epoch 88/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.3873 - accuracy: 0.8685 - val_loss: 0.3887 - val_accuracy: 0.8650
# Epoch 89/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.3916 - accuracy: 0.8652 - val_loss: 0.3909 - val_accuracy: 0.8621
# Epoch 90/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.3898 - accuracy: 0.8654 - val_loss: 0.4003 - val_accuracy: 0.8588
# Epoch 91/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.3860 - accuracy: 0.8681 - val_loss: 0.3984 - val_accuracy: 0.8607
# Epoch 92/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.3901 - accuracy: 0.8677 - val_loss: 0.3960 - val_accuracy: 0.8628
# Epoch 93/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.3864 - accuracy: 0.8692 - val_loss: 0.3873 - val_accuracy: 0.8646
# Epoch 94/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.3898 - accuracy: 0.8670 - val_loss: 0.3818 - val_accuracy: 0.8668
# Epoch 95/100
# 611/611 [==============================] - 3s 4ms/step - loss: 0.3921 - accuracy: 0.8681 - val_loss: 0.3905 - val_accuracy: 0.8628
# Epoch 96/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.3868 - accuracy: 0.8686 - val_loss: 0.3867 - val_accuracy: 0.8625
# Epoch 97/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.3904 - accuracy: 0.8666 - val_loss: 0.3883 - val_accuracy: 0.8614
# Epoch 98/100
# 611/611 [==============================] - 2s 3ms/step - loss: 0.3857 - accuracy: 0.8696 - val_loss: 0.4088 - val_accuracy: 0.8560
# Epoch 99/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.3922 - accuracy: 0.8640 - val_loss: 0.3846 - val_accuracy: 0.8621
# Epoch 100/100
# 611/611 [==============================] - 2s 4ms/step - loss: 0.3883 - accuracy: 0.8659 - val_loss: 0.3912 - val_accuracy: 0.8650
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3396 - accuracy: 0.8830
# Test Loss: 0.33964040875434875
# Test Accuracy: 0.8830034136772156

# %%
model.save('model_type_1.h5')
